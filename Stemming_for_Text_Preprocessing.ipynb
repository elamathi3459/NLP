# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for PorterStemmer: filename=porterstemmer-0.5-cp312-cp312-linux_x86_64.whl size=42251 sha256=1e2e9c2d2f13dfdccf6f451c3f0f6192e7c1adea5de100e82bf021ac9a3f2545
#   Stored in directory: /home/codespace/.cache/pip/wheels/2e/c0/05/5219c00e9f2e7e222526e0898ecd8265cc5abb734f5fd0feb9
# Successfully built PorterStemmer
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %% [markdown]
# ### 1. PorterStemmer

# %%
# Stemming -> Process of reducing a word to word stem
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
words = ["running", "runner", "runs", "easily", "fairly", "singing", "singer", "studying", "flies", "denied", "happiness", "automation"]

for word in words:
    print(f"{word} → {stemmer.stem(word)}")
# Out:
# running → run
# runner → runner
# runs → run
# easily → easili
# fairly → fairli
# singing → sing
# singer → singer
# studying → studi
# flies → fli
# denied → deni
# happiness → happi
# automation → autom

# %%
#cons
stemmer.stem('congratulations')
# Out:
# 'congratul'

# %% [markdown]
# ### 2. RegexpStemmer

# %%
from nltk.stem import RegexpStemmer

regstem= RegexpStemmer('ing$|s$|e$|able$', min=4)

for word in words:
    print(f"{word}-> {regstem.stem(word)}")
# Out:
# running-> runn
# runner-> runner
# runs-> run
# easily-> easily
# fairly-> fairly
# singing-> sing
# singer-> singer
# studying-> study
# flies-> flie
# denied-> denied
# happiness-> happines
# automation-> automation

# %% [markdown]
# ### 3. Snowball Stemmer

# %%
from nltk.stem import SnowballStemmer

snowstem = SnowballStemmer('english')

for word in words:
    print(f"{word}-> {snowstem.stem(word)}")
# Out:
# running-> run
# runner-> runner
# runs-> run
# easily-> easili
# fairly-> fair
# singing-> sing
# singer-> singer
# studying-> studi
# flies-> fli
# denied-> deni
# happiness-> happi
# automation-> autom

# %% [markdown]
# #### Note: Drawback of stemming is rectified using Lemmetization
