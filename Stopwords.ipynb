# %%
corpus = """I have three visions for India. In 3000 years of our history, people from all over the world have come and invaded us, captured our lands, conquered our minds. Yet we have not done this to any other nation. Why? Because we respect the freedom of others. That is why my first vision is that of freedom.

My second vision for India’s development. For fifty years we have been a developing nation. It is time we see ourselves as a developed nation. We are among the top 5 nations in the world in terms of GDP. Our poverty levels are falling. Our achievements are being globally recognized today.

My third vision is that India must stand up to the world. Unless India stands up to the world, no one will respect us. Only strength respects strength. We must be strong not only as a military power but also as an economic power.
"""

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
import nltk
nltk.download('stopwords')
stemmer=PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
documents = nltk.sent_tokenize(corpus)

# %%
#Apply stopwords and filter and then apply stemming
for i in range(len(documents)):
    words = nltk.word_tokenize(documents[i])
    words = [stemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
    documents[i]=' '.join(words)#converting all words intO sentences

# %%
documents
# Out:
# ['three vision india .',
#  '3000 year histori , peopl world come invad us , captur land , conquer mind .',
#  'yet done nation .',
#  'whi ?',
#  'becau respect freedom .',
#  'first vision freedom .',
#  'second vision india ’ develop .',
#  'fifti year develop nation .',
#  'time see develop nation .',
#  'among top 5 nation world term gdp .',
#  'poverti level fall .',
#  'achiev global recogn today .',
#  'third vision india must stand world .',
#  'unless india stand world , one respect us .',
#  'onli strength respect strength .',
#  'must strong militari power also econom power .']

# %%
#Apply stopwords and filter and then apply stemming
from nltk.stem import SnowballStemmer
snowstem = SnowballStemmer('english')
for i in range(len(documents)):
    words = nltk.word_tokenize(documents[i])
    words = [snowstem.stem(word) for word in words if word not in set(stopwords.words('english'))]
    documents[i]=' '.join(words)#converting all words intO sentences

# %%
documents
# Out:
# ['i three vision india .',
#  'in 3000 year histori , peopl world come invad us , captur land , conquer mind .',
#  'yet done nation .',
#  'whi ?',
#  'becaus respect freedom other .',
#  'that first vision freedom .',
#  'my second vision india ’ develop .',
#  'for fifti year develop nation .',
#  'it time see develop nation .',
#  'we among top 5 nation world term gdp .',
#  'our poverti level fall .',
#  'our achiev global recogn today .',
#  'my third vision india must stand world .',
#  'unless india stand world , one respect us .',
#  'onli strength respect strength .',
#  'we must strong militari power also econom power .']
